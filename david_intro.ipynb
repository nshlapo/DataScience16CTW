# %%
import pandas as pd
import os
import csv

# %%
cur_dir = os.path.dirname('__file__')
data = pd.read_csv(os.path.join(cur_dir, "WDI_Data.csv"))

# %%
def preprocess(df):
    df = df.copy()
    df['21st'] = df.ix[:, '2000':].mean(axis=1)
    return df

# %%
data = preprocess(data)

# %%
def one_year(data, year='21st'):
    grouped = data.groupby('Indicator Name')
    indic_dict = {}
    for indicator, group in grouped:
        for index, row in group.iterrows():
            if indicator not in indic_dict:
                indic_dict[indicator] = []
            indic_dict[indicator].append(row[year])
    for indicator, group in grouped:
        names = group['Country Name'].tolist()
        break   
        
    return pd.DataFrame(indic_dict, index=names)

# %%
millenial_avg = one_year(data)

# %%
null_pcts = []

for column in millenial_avg.columns:
    col = millenial_avg[column]
    null_pct = float(col.notnull().sum()) / len(col)
    null_pcts.append((column, null_pct))
    
null_pcts = sorted(null_pcts, key=lambda x: x[1], reverse=True)

for cat, perc in null_pcts:
    print "%s: %.1f" % (cat, perc * 100)
# Out:
# Population growth (annual %): 99.6
# Population, total: 99.6
# Surface area (sq. km): 99.6
# Land area (sq. km): 99.2
# Population density (people per sq. km of land area): 99.2
# Access to electricity (% of population): 98.8
# Access to electricity, rural (% of rural population): 98.8
# Access to electricity, urban (% of urban population): 98.8
# Bird species, threatened: 98.8
# Fish species, threatened: 98.8
# Mammal species, threatened: 98.8
# Plant species (higher), threatened: 98.8
# Rural population: 98.8
# Rural population (% of total population): 98.8
# Urban population: 98.8
# Urban population (% of total): 98.8
# Urban population growth (annual %): 98.8
# Secure Internet servers: 98.4
# Secure Internet servers (per 1 million people): 98.4
# Birth rate, crude (per 1,000 people): 98.0
# Death rate, crude (per 1,000 people): 98.0
# Agricultural land (sq. km): 97.6
# Forest area (sq. km): 97.6
# International migrant stock (% of population): 97.6
# International migrant stock, total: 97.6
# Agricultural land (% of land area): 97.2
# Fixed telephone subscriptions: 97.2
# Fixed telephone subscriptions (per 100 people): 97.2
# Mobile cellular subscriptions: 97.2
# Mobile cellular subscriptions (per 100 people): 97.2
# Arable land (% of land area): 96.8
# Arable land (hectares per person): 96.8
# Diabetes prevalence (% of population ages 20 to 79): 96.8
# Fertility rate, total (births per woman): 96.8
# Forest area (% of land area): 96.8
# Land area where elevation is below 5 meters (% of total land area): 96.8
# Life expectancy at birth, female (years): 96.8
# Life expectancy at birth, male (years): 96.8
# Life expectancy at birth, total (years): 96.8
# Population living in areas where elevation is below 5 meters (% of total population): 96.8
# GDP at market prices (current US$): 96.0
# GDP per capita (current US$): 96.0
# Intentional homicides (per 100,000 people): 96.0
# Internet users (per 100 people): 96.0
# Rural population growth (annual %): 96.0
# Terrestrial and marine protected areas (% of total territorial area): 96.0
# Coal rents (% of GDP): 95.6
# Fixed broadband subscriptions: 95.6
# Fixed broadband subscriptions (per 100 people): 95.6
# Mineral rents (% of GDP): 95.6
# Oil rents (% of GDP): 95.6
# Terrestrial protected areas (% of total land area): 95.6
# GNI (current US$): 95.2
# Natural gas rents (% of GDP): 95.2
# Adjusted savings: energy depletion (% of GNI): 94.8
# Adjusted savings: mineral depletion (% of GNI): 94.8
# GDP growth (annual %): 94.8
# GDP per capita growth (annual %): 94.8
# Inflation, GDP deflator (annual %): 94.8
# International tourism, number of arrivals: 94.8
# GNI per capita, Atlas method (current US$): 94.4
# GNI, Atlas method (current US$): 94.4
# Improved water source (% of population with access): 94.4
# Improved water source, urban (% of urban population with access): 94.4
# Food production index (2004-2006 = 100): 94.0
# Improved sanitation facilities (% of population with access): 94.0
# Improved sanitation facilities, urban (% of urban population with access): 94.0
# Refugee population by country or territory of origin: 94.0
# CO2 emissions (kt): 93.5
# CO2 emissions (metric tons per capita): 93.5
# CO2 emissions from gaseous fuel consumption (% of total): 93.5
# CO2 emissions from liquid fuel consumption (% of total): 93.5
# CO2 emissions from liquid fuel consumption (kt): 93.5
# CO2 emissions from solid fuel consumption (% of total): 93.5
# Enrolment in primary education, both sexes (number): 93.5
# Foreign direct investment, net inflows (BoP, current US$): 93.5
# GDP at market prices (constant 2005 US$): 93.5
# GDP per capita (constant 2005 US$): 93.5
# Livestock production index (2004-2006 = 100): 93.5
# Merchandise exports (current US$): 93.5
# Percentage of students in primary education who are female (%): 93.5
# Crop production index (2004-2006 = 100): 93.1
# Enrolment in secondary general, both sexes (number): 93.1
# Improved water source, rural (% of rural population with access): 93.1
# Merchandise imports (current US$): 93.1
# Percentage of students in secondary general education who are female (%): 93.1
# Improved sanitation facilities, rural (% of rural population with access): 92.7
# International tourism, receipts (current US$): 92.7
# Mortality rate, adult, female (per 1,000 female adults): 92.7
# Mortality rate, adult, male (per 1,000 male adults): 92.7
# Adjusted savings: consumption of fixed capital (% of GNI): 92.3
# Enrolment in secondary education, both sexes (number): 92.3
# GNI (constant 2005 US$): 92.3
# GNI per capita (constant 2005 US$): 92.3
# Incidence of tuberculosis (per 100,000 people): 92.3
# Other greenhouse gas emissions, HFC, PFC and SF6 (thousand metric tons of CO2 equivalent): 92.3
# Age dependency ratio (% of working-age population): 91.9
# Age dependency ratio, old (% of working-age population): 91.9
# Age dependency ratio, young (% of working-age population): 91.9
# Percentage of students in secondary education who are female (%): 91.9
# Permanent cropland (% of land area): 91.9
# Population ages 65 and above (% of total): 91.9
# Population, ages 0-14 (% of total): 91.9
# Population, ages 15-64 (% of total): 91.9
# Population, female (% of total): 91.9
# Tuberculosis case detection rate (%, all forms): 91.9
# Adolescent fertility rate (births per 1,000 women ages 15-19): 91.5
# Foreign direct investment, net inflows (% of GDP): 91.5
# Net migration: 91.5
# Survival to age 65, female (% of cohort): 91.5
# Survival to age 65, male (% of cohort): 91.5
# Adjusted savings: carbon dioxide damage (% of GNI): 91.1
# Merchandise trade (% of GDP): 91.1
# CO2 emissions (kg per 2005 US$ of GDP): 90.7
# Exports of goods and services (% of GDP): 90.7
# External balance on goods and services (% of GDP): 90.7
# GDP per capita, PPP (constant 2011 international $): 90.7
# GDP per capita, PPP (current international $): 90.7
# GDP, PPP (constant 2011 international $): 90.7
# GDP, PPP (current international $): 90.7
# Imports of goods and services (% of GDP): 90.7
# Mortality rate, infant (per 1,000 live births): 90.7
# Mortality rate, infant, female (per 1,000 live births): 90.7
# Mortality rate, infant, male (per 1,000 live births): 90.7
# Mortality rate, neonatal (per 1,000 live births): 90.7
# Mortality rate, under-5 (per 1,000): 90.7
# Mortality rate, under-5, female (per 1,000 live births): 90.7
# Mortality rate, under-5, male (per 1,000 live births): 90.7
# Pupil-teacher ratio in primary education (headcount basis): 90.7
# Teachers in primary education, both sexes (number): 90.7
# Trade (% of GDP): 90.7
# Access to non-solid fuel (% of population): 90.3
# Access to non-solid fuel, rural (% of rural population): 90.3
# Access to non-solid fuel, urban (% of urban population): 90.3
# CO2 emissions from gaseous fuel consumption (kt): 90.3
# Emigration rate of tertiary educated (% of total tertiary educated population): 90.3
# Exports of goods and services (current US$): 90.3
# Gross national expenditure (current US$): 90.3
# Immunization, DPT (% of children ages 12-23 months): 90.3
# Immunization, measles (% of children ages 12-23 months): 90.3
# Imports of goods and services (current US$): 90.3
# International tourism, expenditures (current US$): 90.3
# Percentage of teachers in primary education who are female (%): 90.3
# Proportion of seats held by women in national parliaments (%): 90.3
# Scientific and technical journal articles: 90.3
# Adjusted savings: education expenditure (% of GNI): 89.9
# Energy intensity level of primary energy (MJ/$2011 PPP GDP): 89.9
# Gross enrolment ratio, primary, both sexes (%): 89.9
# Gross enrolment ratio, primary, female (%): 89.9
# Gross enrolment ratio, primary, gender parity index (GPI): 89.9
# Gross enrolment ratio, primary, male (%): 89.9
# Physicians (per 1,000 people): 89.9
# Refugee population by country or territory of asylum: 89.9
# Tuberculosis treatment success rate (% of new cases): 89.9
# Agriculture, value added (current US$): 89.5
# CO2 emissions from solid fuel consumption (kt): 89.5
# GNI per capita, PPP (current international $): 89.5
# GNI, PPP (current international $): 89.5
# Low-birthweight babies (% of births): 89.5
# Renewable electricity output (% of total electricity output): 89.5
# Business extent of disclosure index (0=less disclosure to 10=more disclosure): 89.1
# CO2 emissions (kg per 2011 PPP $ of GDP): 89.1
# CO2 emissions (kg per PPP $ of GDP): 89.1
# Cost of business start-up procedures (% of GNI per capita): 89.1
# Cost to export (US$ per container): 89.1
# Cost to import (US$ per container): 89.1
# Depth of credit information index (0=low to 8=high): 89.1
# Distance to frontier score (0=lowest performance to 100=frontier): 89.1
# Documents to export (number): 89.1
# Documents to import (number): 89.1
# Ease of doing business index (1=most business-friendly regulations): 89.1
# General government final consumption expenditure (% of GDP): 89.1
# General government final consumption expenditure (current US$): 89.1
# Gross enrolment ratio, secondary, both sexes (%): 89.1
# Health expenditure per capita (current US$): 89.1
# Health expenditure per capita, PPP (constant 2011 international $): 89.1
# Health expenditure, private (% of GDP): 89.1
# Health expenditure, public (% of GDP): 89.1
# Health expenditure, public (% of total health expenditure): 89.1
# Health expenditure, total (% of GDP): 89.1
# Industry, value added (current US$): 89.1
# Merchandise exports by the reporting economy (current US$): 89.1
# Merchandise exports by the reporting economy, residual (% of total merchandise exports): 89.1
# Merchandise exports to high-income economies (% of total merchandise exports): 89.1
# Merchandise imports by the reporting economy (current US$): 89.1
# Merchandise imports by the reporting economy, residual (% of total merchandise imports): 89.1
# Out-of-pocket health expenditure (% of private expenditure on health): 89.1
# Out-of-pocket health expenditure (% of total expenditure on health): 89.1
# Private credit bureau coverage (% of adults): 89.1
# Public credit registry coverage (% of adults): 89.1
# Services, etc., value added (current US$): 89.1
# Start-up procedures to register a business (number): 89.1
# Strength of legal rights index (0=weak to 12=strong): 89.1
# Tax payments (number): 89.1
# Time required to enforce a contract (days): 89.1
# Time required to get electricity (days): 89.1
# Time required to start a business (days): 89.1
# Time to export (days): 89.1
# Time to import (days): 89.1
# Time to prepare and pay taxes (hours): 89.1
# Total tax rate (% of commercial profits): 89.1
# Agriculture, value added (% of GDP): 88.7
# Gross capital formation (% of GDP): 88.7
# Gross domestic savings (% of GDP): 88.7
# Gross enrolment ratio, pre-primary, both sexes (%): 88.7
# Gross enrolment ratio, secondary, female (%): 88.7
# Gross enrolment ratio, secondary, gender parity index (GPI): 88.7
# Gross enrolment ratio, secondary, male (%): 88.7
# Industry, value added (% of GDP): 88.7
# International tourism, receipts for travel items (current US$): 88.7
# Merchandise imports from high-income economies (% of total merchandise imports): 88.7
# Nurses and midwives (per 1,000 people): 88.7
# PM2.5 air pollution, mean annual exposure (micrograms per cubic meter): 88.7
# Percentage of enrolment in primary education in private institutions (%): 88.7
# Final consumption expenditure, etc. (current US$): 88.3
# Forest rents (% of GDP): 88.3
# Gross capital formation (current US$): 88.3
# Gross domestic savings (current US$): 88.3
# Gross fixed capital formation (% of GDP): 88.3
# Household final consumption expenditure, etc. (% of GDP): 88.3
# Household final consumption expenditure, etc. (current US$): 88.3
# International tourism, expenditures for travel items (current US$): 88.3
# Labor force participation rate for ages 15-24, female (%) (modeled ILO estimate): 88.3
# Labor force participation rate for ages 15-24, male (%) (modeled ILO estimate): 88.3
# Labor force participation rate for ages 15-24, total (%) (modeled ILO estimate): 88.3
# Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate): 88.3
# Labor force participation rate, female (% of female population ages 15-64) (modeled ILO estimate): 88.3
# Labor force participation rate, male (% of male population ages 15+) (modeled ILO estimate): 88.3
# Labor force participation rate, male (% of male population ages 15-64) (modeled ILO estimate): 88.3
# Labor force participation rate, total (% of total population ages 15+) (modeled ILO estimate): 88.3
# Labor force participation rate, total (% of total population ages 15-64) (modeled ILO estimate): 88.3
# Labor force, female (% of total labor force): 88.3
# Labor force, total: 88.3
# Manufacturing, value added (current US$): 88.3
# PM2.5 air pollution, population exposed to levels exceeding WHO guideline value (% of total): 88.3
# Procedures to build a warehouse (number): 88.3
# Ratio of female to male labor force participation rate (%) (modeled ILO estimate): 88.3
# Renewable energy consumption (% of total final energy consumption): 88.3
# Services, etc., value added (% of GDP): 88.3
# Time required to build a warehouse (days): 88.3
# Total natural resources rents (% of GDP): 88.3
# Commercial bank branches (per 100,000 adults): 87.9
# Gross enrolment ratio, primary and secondary, gender parity index (GPI): 87.9
# Gross fixed capital formation (current US$): 87.9
# Household final consumption expenditure (current US$): 87.9
# Prevalence of anemia among children (% of children under 5): 87.9
# Prevalence of anemia among non-pregnant women (% of women ages 15-49): 87.9
# Prevalence of anemia among pregnant women (%): 87.9
# Agricultural raw materials imports (% of merchandise imports): 87.5
# Exports of goods and services (constant 2005 US$): 87.5
# Food imports (% of merchandise imports): 87.5
# Fuel imports (% of merchandise imports): 87.5
# Gross enrolment ratio, pre-primary, female (%): 87.5
# Gross enrolment ratio, pre-primary, male (%): 87.5
# Gross national expenditure (constant 2005 US$): 87.5
# ICT goods imports (% total goods imports): 87.5
# Imports of goods and services (constant 2005 US$): 87.5
# Manufactures imports (% of merchandise imports): 87.5
# Manufacturing, value added (% of GDP): 87.5
# Ores and metals imports (% of merchandise imports): 87.5
# Personal remittances, paid (current US$): 87.5
# Procedures to register property (number): 87.5
# Time required to register property (days): 87.5
# Automated teller machines (ATMs) (per 100,000 adults): 87.1
# Commercial service exports (current US$): 87.1
# Commercial service imports (current US$): 87.1
# Exports of goods and services (BoP, current US$): 87.1
# Exports of goods, services and primary income (BoP, current US$): 87.1
# Food exports (% of merchandise exports): 87.1
# Goods exports (BoP, current US$): 87.1
# Goods imports (BoP, current US$): 87.1
# Gross enrolment ratio, tertiary, both sexes (%): 87.1
# Gross intake ratio to Grade 1 of primary education, both sexes (%): 87.1
# Imports of goods and services (BoP, current US$): 87.1
# Imports of goods, services and primary income (BoP, current US$): 87.1
# Labor force participation rate, total (% of total population ages 15+) (national estimate): 87.1
# Lifetime risk of maternal death (%): 87.1
# Lifetime risk of maternal death (1 in: rate varies by country): 87.1
# Manufactures exports (% of merchandise exports): 87.1
# Maternal mortality ratio (modeled estimate, per 100,000 live births): 87.1
# Number of maternal deaths: 87.1
# Percentage of enrolment in secondary education in private institutions (%): 87.1
# Personal remittances, received (current US$): 87.1
# Service exports (BoP, current US$): 87.1
# Service imports (BoP, current US$): 87.1
# Agricultural raw materials exports (% of merchandise exports): 86.7
# Agriculture, value added (annual % growth): 86.7
# Communications, computer, etc. (% of service exports, BoP): 86.7
# Communications, computer, etc. (% of service imports, BoP): 86.7
# Computer, communications and other services (% of commercial service exports): 86.7
# Computer, communications and other services (% of commercial service imports): 86.7
# Enrolment in secondary vocational, both sexes (number): 86.7
# Insurance and financial services (% of commercial service imports): 86.7
# Insurance and financial services (% of service imports, BoP): 86.7
# Ores and metals exports (% of merchandise exports): 86.7
# Primary income payments (BoP, current US$): 86.7
# Primary income receipts (BoP, current US$): 86.7
# Services, etc., value added (constant 2005 US$): 86.7
# Transport services (% of commercial service imports): 86.7
# Transport services (% of service imports, BoP): 86.7
# Travel services (% of commercial service exports): 86.7
# Travel services (% of commercial service imports): 86.7
# Travel services (% of service exports, BoP): 86.7
# Travel services (% of service imports, BoP): 86.7
# Adjusted savings: energy depletion (current US$): 86.3
# Adjusted savings: mineral depletion (current US$): 86.3
# Agriculture, value added (constant 2005 US$): 86.3
# Births attended by skilled health staff (% of total): 86.3
# Gross intake ratio to Grade 1 of primary education, female (%): 86.3
# Gross intake ratio to Grade 1 of primary education, male (%): 86.3
# Industry, value added (constant 2005 US$): 86.3
# International tourism, expenditures (% of total imports): 86.3
# International tourism, receipts (% of total exports): 86.3
# Trade in services (% of GDP): 86.3
# Transport services (% of commercial service exports): 86.3
# Transport services (% of service exports, BoP): 86.3
# Cereal production (metric tons): 85.9
# Fuel exports (% of merchandise exports): 85.9
# General government final consumption expenditure (constant 2005 US$): 85.9
# Gross capital formation (constant 2005 US$): 85.9
# Gross enrolment ratio, tertiary, female (%): 85.9
# Gross enrolment ratio, tertiary, gender parity index (GPI): 85.9
# Gross enrolment ratio, tertiary, male (%): 85.9
# High-technology exports (% of manufactured exports): 85.9
# High-technology exports (current US$): 85.9
# Hospital beds (per 1,000 people): 85.9
# Industry, value added (annual % growth): 85.9
# Land under cereal production (hectares): 85.9
# Secondary income receipts (BoP, current US$): 85.9
# Services, etc., value added (annual % growth): 85.9
# Unemployment, total (% of total labor force) (national estimate): 85.9
# Agriculture value added per worker (constant 2005 US$): 85.5
# Annual freshwater withdrawals, total (billion cubic meters): 85.5
# GNI per capita, PPP (constant 2011 international $): 85.5
# GNI, PPP (constant 2011 international $): 85.5
# Merchandise imports from developing economies in South Asia (% of total merchandise imports): 85.5
# Personal remittances, received (% of GDP): 85.5
# Pump price for gasoline (US$ per liter): 85.5
# Secondary income, other sectors, payments (BoP, current US$): 85.5
# Cereal yield (kg per hectare): 85.1
# Final consumption expenditure, etc. (constant 2005 US$): 85.1
# Health expenditure, public (% of government expenditure): 85.1
# Household final consumption expenditure, etc. (constant 2005 US$): 85.1
# Percentage of repeaters in primary education, all grades, both sexes (%): 85.1
# Percentage of students in secondary vocational education who are female (%): 85.1
# Renewable internal freshwater resources per capita (cubic meters): 85.1
# Renewable internal freshwater resources, total (billion cubic meters): 85.1
# Unemployment, female (% of female labor force) (national estimate): 85.1
# Unemployment, male (% of male labor force) (national estimate): 85.1
# Adjusted savings: gross savings (% of GNI): 84.7
# Household final consumption expenditure, PPP (current international $): 84.7
# ICT goods exports (% of total goods exports): 84.7
# Labor tax and contributions (% of commercial profits): 84.7
# Manufacturing, value added (annual % growth): 84.7
# Merchandise imports from developing economies in Middle East & North Africa (% of total merchandise imports): 84.7
# Other taxes payable by businesses (% of commercial profits): 84.7
# Profit tax (% of commercial profits): 84.7
# Adjusted net enrolment rate, primary, both sexes (%): 84.3
# Adjusted savings: net national savings (% of GNI): 84.3
# Employment to population ratio, 15+, total (%) (national estimate): 84.3
# Gross fixed capital formation (constant 2005 US$): 84.3
# Household final consumption expenditure (constant 2005 US$): 84.3
# Household final consumption expenditure per capita (constant 2005 US$): 84.3
# Inflation, consumer prices (annual %): 84.3
# Manufacturing, value added (constant 2005 US$): 84.3
# Net bilateral aid flows from DAC donors, Total (current US$): 84.3
# Net enrolment rate, primary, both sexes (%): 84.3
# Net official development assistance and official aid received (constant 2012 US$): 84.3
# Net official development assistance and official aid received (current US$): 84.3
# Out-of-school children of primary school age, both sexes (number): 84.3
# Primary completion rate, both sexes (%): 84.3
# Pump price for diesel fuel (US$ per liter): 84.3
# Teachers in secondary education, both sexes (number): 84.3
# Adjusted savings: natural resources depletion (% of GNI): 83.9
# Adjusted savings: net forest depletion (% of GNI): 83.9
# Gross savings (% of GDP): 83.9
# Gross savings (% of GNI): 83.9
# Merchandise exports to economies in the Arab World (% of total merchandise exports): 83.9
# Percentage of repeaters in primary education, all grades, female (%): 83.9
# Percentage of repeaters in primary education, all grades, male (%): 83.9
# Percentage of repeaters in secondary general education, all grades, both sexes (%): 83.9
# Pupil-teacher ratio in secondary education (headcount basis): 83.9
# Total reserves in months of imports: 83.9
# Water productivity, total (constant 2005 US$ GDP per cubic meter of total freshwater withdrawal): 83.9
# Annual freshwater withdrawals, agriculture (% of total freshwater withdrawal): 83.5
# Annual freshwater withdrawals, domestic (% of total freshwater withdrawal): 83.5
# Annual freshwater withdrawals, industry (% of total freshwater withdrawal): 83.5
# Arable land (hectares): 83.5
# Merchandise exports to developing economies in Middle East & North Africa (% of total merchandise exports): 83.5
# Merchandise exports to developing economies in South Asia (% of total merchandise exports): 83.5
# Number of neonatal deaths: 83.5
# Primary completion rate, female (%): 83.5
# Primary completion rate, male (%): 83.5
# Adjusted net enrolment rate, primary, female (%): 83.1
# Adjusted net enrolment rate, primary, male (%): 83.1
# Adjusted net national income (current US$): 83.1
# Adjusted net national income per capita (current US$): 83.1
# DEC alternative conversion factor (LCU per US$): 83.1
# Employment to population ratio, 15+, female (%) (modeled ILO estimate): 83.1
# Employment to population ratio, 15+, male (%) (modeled ILO estimate): 83.1
# Employment to population ratio, 15+, total (%) (modeled ILO estimate): 83.1
# Employment to population ratio, ages 15-24, female (%) (modeled ILO estimate): 83.1
# Employment to population ratio, ages 15-24, male (%) (modeled ILO estimate): 83.1
# Employment to population ratio, ages 15-24, total (%) (modeled ILO estimate): 83.1
# External resources for health (% of total expenditure on health): 83.1
# Final consumption expenditure (constant 2005 US$): 83.1
# GDP (current LCU): 83.1
# GDP per capita (current LCU): 83.1
# Insurance and financial services (% of commercial service exports): 83.1
# Insurance and financial services (% of service exports, BoP): 83.1
# Net enrolment rate, primary, female (%): 83.1
# Net enrolment rate, primary, male (%): 83.1
# Out-of-school children of primary school age, female (number): 83.1
# Out-of-school children of primary school age, male (number): 83.1
# Percentage of repeaters in secondary general education, all grades, female (%): 83.1
# Percentage of repeaters in secondary general education, all grades, male (%): 83.1
# Unemployment, female (% of female labor force): 83.1
# Unemployment, male (% of male labor force): 83.1
# Unemployment, total (% of total labor force): 83.1
# Unemployment, youth female (% of female labor force ages 15-24) (modeled ILO estimate): 83.1
# Unemployment, youth male (% of male labor force ages 15-24) (modeled ILO estimate): 83.1
# Unemployment, youth total (% of total labor force ages 15-24) (modeled ILO estimate): 83.1
# GEF benefits index for biodiversity (0 = no biodiversity potential to 100 = maximum): 82.7
# Labor force participation rate, female (% of female population ages 15+) (national estimate): 82.7
# Labor force participation rate, male (% of male population ages 15+) (national estimate): 82.7
# Net official flows from UN agencies, UNTA (current US$): 82.7
# Number of infant deaths: 82.7
# Number of under-five deaths: 82.7
# Official entrance age to primary education (years): 82.7
# Percentage of teachers in secondary education who are female (%): 82.7
# Ratio of female to male labor force participation rate (%) (national estimate): 82.7
# Teachers in secondary education, female (number): 82.7
# Theoretical duration of primary education (years): 82.7
# Adjusted savings: consumption of fixed capital (current US$): 82.3
# Air transport, passengers carried: 82.3
# Air transport, registered carrier departures worldwide: 82.3
# Annual freshwater withdrawals, total (% of internal resources): 82.3
# Armed forces personnel, total: 82.3
# Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions (% of total): 82.3
# Cause of death, by injury (% of total): 82.3
# Cause of death, by non-communicable diseases (% of total): 82.3
# Merchandise imports from economies in the Arab World (% of total merchandise imports): 82.3
# Net bilateral aid flows from DAC donors, France (current US$): 82.3
# PPP conversion factor, private consumption (LCU per international $): 82.3
# Survival rate to the last grade of primary education, both sexes (%): 82.3
# Air transport, freight (million ton-km): 81.9
# GNI (current LCU): 81.9
# GNI per capita (current LCU): 81.9
# Lower secondary completion rate, both sexes (%): 81.9
# Net bilateral aid flows from DAC donors, Germany (current US$): 81.9
# GDP (constant LCU): 81.5
# GDP deflator (base year varies by country): 81.5
# GDP per capita (constant LCU): 81.5
# Lower secondary completion rate, female (%): 81.5
# Lower secondary completion rate, male (%): 81.5
# Official entrance age to lower secondary education (years): 81.5
# Share of tariff lines with international peaks, all products (%): 81.5
# Share of tariff lines with international peaks, manufactured products (%): 81.5
# Share of tariff lines with international peaks, primary products (%): 81.5
# Share of tariff lines with specific rates, all products (%): 81.5
# Share of tariff lines with specific rates, manufactured products (%): 81.5
# Share of tariff lines with specific rates, primary products (%): 81.5
# Tariff rate, applied, simple mean, all products (%): 81.5
# Tariff rate, applied, simple mean, manufactured products (%): 81.5
# Tariff rate, applied, simple mean, primary products (%): 81.5
# Tariff rate, applied, weighted mean, all products (%): 81.5
# Tariff rate, applied, weighted mean, manufactured products (%): 81.5
# Tariff rate, applied, weighted mean, primary products (%): 81.5
# Tariff rate, most favored nation, simple mean, all products (%): 81.5
# Tariff rate, most favored nation, simple mean, manufactured products (%): 81.5
# Tariff rate, most favored nation, simple mean, primary products (%): 81.5
# Tariff rate, most favored nation, weighted mean, all products (%): 81.5
# Tariff rate, most favored nation, weighted mean, manufactured products (%): 81.5
# Tariff rate, most favored nation, weighted mean, primary products (%): 81.5
# Theoretical duration of secondary education (years): 81.5
# Armed forces personnel (% of total labor force): 81.0
# Employment in agriculture (% of total employment): 81.0
# Employment in industry (% of total employment): 81.0
# Employment in services (% of total employment): 81.0
# Net bilateral aid flows from DAC donors, Japan (current US$): 81.0
# Adjusted net national income (constant 2005 US$): 80.6
# Adjusted net national income per capita (constant 2005 US$): 80.6
# Adjusted savings: particulate emission damage (% of GNI): 80.6
# CO2 intensity (kg per kg of oil equivalent energy use): 80.6
# Fossil fuel energy consumption (% of total): 80.6
# International tourism, expenditures for passenger transport items (current US$): 80.6
# Net bilateral aid flows from DAC donors, United States (current US$): 80.6
# Net official flows from UN agencies, UNDP (current US$): 80.6
# Time to resolve insolvency (years): 80.6
# Adjusted savings: carbon dioxide damage (current US$): 80.2
# Energy use (kg of oil equivalent per capita): 80.2
# Export value index (2000 = 100): 80.2
# Export volume index (2000 = 100): 80.2
# Gross value added at factor cost (current US$): 80.2
# Import value index (2000 = 100): 80.2
# Import volume index (2000 = 100): 80.2
# Imports of goods and services (annual % growth): 80.2
# Net barter terms of trade index (2000 = 100): 80.2
# Net bilateral aid flows from DAC donors, European Union institutions (current US$): 80.2
# PPP conversion factor, GDP (LCU per international $): 80.2
# Portfolio equity, net inflows (BoP, current US$): 80.2
# Exports of goods and services (annual % growth): 79.8
# Logistics performance index: Ability to track and trace consignments (1=low to 5=high): 79.8
# Logistics performance index: Competence and quality of logistics services (1=low to 5=high): 79.8
# Logistics performance index: Ease of arranging competitively priced shipments (1=low to 5=high): 79.8
# Logistics performance index: Efficiency of customs clearance process (1=low to 5=high): 79.8
# Logistics performance index: Frequency with which shipments reach consignee within scheduled or expected time (1=low to 5=high): 79.8
# Logistics performance index: Overall (1=low to 5=high): 79.8
# Logistics performance index: Quality of trade and transport-related infrastructure (1=low to 5=high): 79.8
# Net income from abroad (current LCU): 79.8
# Arms imports (SIPRI trend indicator values): 79.4
# Employment to population ratio, 15+, female (%) (national estimate): 79.4
# Employment to population ratio, 15+, male (%) (national estimate): 79.4
# Household final consumption expenditure, PPP (constant 2011 international $): 79.4
# Merchandise exports to developing economies in Latin America & the Caribbean (% of total merchandise exports): 79.4
# Merchandise imports from developing economies outside region (% of total merchandise imports): 79.4
# Net bilateral aid flows from DAC donors, Canada (current US$): 79.4
# Net bilateral aid flows from DAC donors, United Kingdom (current US$): 79.4
# Net income from abroad (current US$): 79.4
# Survival rate to the last grade of primary education, female (%): 79.4
# Survival rate to the last grade of primary education, male (%): 79.4
# GNI growth (annual %): 79.0
# GNI per capita growth (annual %): 79.0
# Merchandise imports from developing economies in Latin America & the Caribbean (% of total merchandise imports): 79.0
# Merchandise imports from developing economies in Sub-Saharan Africa (% of total merchandise imports): 79.0
# Primary to secondary general education transition rate, both sexes (%): 79.0
# Net bilateral aid flows from DAC donors, Korea, Rep. (current US$): 78.6
# Adjusted net savings, excluding particulate emission damage (% of GNI): 78.2
# Gross capital formation (annual % growth): 78.2
# ICT service exports (BoP, current US$): 78.2
# Merchandise exports to developing economies outside region (% of total merchandise exports): 78.2
# Percentage of teachers in tertiary education who are female (%): 78.2
# Energy use (kg of oil equivalent) per $1,000 GDP (constant 2011 PPP): 77.8
# Final consumption expenditure, etc. (annual % growth): 77.8
# GDP per unit of energy use (PPP $ per kg of oil equivalent): 77.8
# GDP per unit of energy use (constant 2011 PPP $ per kg of oil equivalent): 77.8
# Gross value added at factor cost (constant 2005 US$): 77.8
# ICT service exports (% of service exports, BoP): 77.8
# Military expenditure (% of GDP): 77.8
# Net bilateral aid flows from DAC donors, Netherlands (current US$): 77.8
# Share of women in wage employment in the nonagricultural sector (% of total nonagricultural employment): 77.8
# Wage and salaried workers, total (% of total employed): 77.8
# Employment in agriculture, female (% of female employment): 77.4
# Employment in agriculture, male (% of male employment): 77.4
# Employment in industry, female (% of female employment): 77.4
# Employment in industry, male (% of male employment): 77.4
# Employment in services, female (% of female employment): 77.4
# Employment in services, male (% of male employment): 77.4
# Exports of goods and services (current LCU): 77.4
# External balance on goods and services (current LCU): 77.4
# Gross national expenditure (current LCU): 77.4
# Imports of goods and services (current LCU): 77.4
# Merchandise exports to developing economies in Sub-Saharan Africa (% of total merchandise exports): 77.4
# Net bilateral aid flows from DAC donors, Spain (current US$): 77.4
# Price level ratio of PPP conversion factor (GDP) to market exchange rate: 77.4
# Primary to secondary general education transition rate, female (%): 77.4
# Primary to secondary general education transition rate, male (%): 77.4
# Contraceptive prevalence (% of women ages 15-49): 77.0
# External balance on goods and services (current US$): 77.0
# Household final consumption expenditure (annual % growth): 77.0
# Net enrolment rate, secondary, both sexes (%): 77.0
# Net enrolment rate, secondary, female (%): 77.0
# Net enrolment rate, secondary, male (%): 77.0
# Adjusted savings: education expenditure (current US$): 76.6
# Agriculture, value added (current LCU): 76.6
# Average precipitation in depth (mm per year): 76.6
# General government final consumption expenditure (annual % growth): 76.6
# Household final consumption expenditure, etc. (annual % growth): 76.6
# Industry, value added (current LCU): 76.6
# Charges for the use of intellectual property, payments (BoP, current US$): 76.2
# Completeness of birth registration (%): 76.2
# Gross fixed capital formation (annual % growth): 76.2
# Labor force participation rate for ages 15-24, female (%) (national estimate): 76.2
# Labor force participation rate for ages 15-24, male (%) (national estimate): 76.2
# Labor force participation rate for ages 15-24, total (%) (national estimate): 76.2
# Services, etc., value added (current LCU): 76.2
# Fertilizer consumption (kilograms per hectare of arable land): 75.8
# General government final consumption expenditure (current LCU): 75.8
# Interest rate spread (lending rate minus deposit rate, %): 75.8
# Pregnant women receiving prenatal care (%): 75.8
# Final consumption expenditure, etc. (% of GDP): 75.4
# Final consumption expenditure, etc. (current LCU): 75.4
# Gross capital formation (current LCU): 75.4
# Gross domestic savings (current LCU): 75.4
# Gross national expenditure (% of GDP): 75.4
# Manufacturing, value added (current LCU): 75.4
# Merchandise imports from developing economies in East Asia & Pacific (% of total merchandise imports): 75.4
# Net bilateral aid flows from DAC donors, Greece (current US$): 75.4
# Net bilateral aid flows from DAC donors, Italy (current US$): 75.4
# Net secondary income (BoP, current US$): 75.4
# Adult literacy rate, population 15+ years, both sexes (%): 75.0
# Adult literacy rate, population 15+ years, female (%): 75.0
# Adult literacy rate, population 15+ years, male (%): 75.0
# Gross fixed capital formation (current LCU): 75.0
# Household final consumption expenditure, etc. (current LCU): 75.0
# Unemployment, youth total (% of total labor force ages 15-24) (national estimate): 75.0
# Final consumption expenditure (current LCU): 74.6
# Household final consumption expenditure (current LCU): 74.6
# Net bilateral aid flows from DAC donors, Australia (current US$): 74.6
# Trademark applications, total: 74.6
# Youth literacy rate, population 15-24 years, both sexes (%): 74.6
# 2005 PPP conversion factor, GDP (LCU per international $): 74.2
# 2005 PPP conversion factor, private consumption (LCU per international $): 74.2
# Agriculture, value added (constant LCU): 74.2
# Compensation of employees (% of expense): 74.2
# Discrepancy in expenditure estimate of GDP (current LCU): 74.2
# Final consumption expenditure (current US$): 74.2
# Goods and services expense (% of expense): 74.2
# Grants and other revenue (% of revenue): 74.2
# Net bilateral aid flows from DAC donors, Austria (current US$): 74.2
# Personal transfers, receipts (BoP, current US$): 74.2
# Self-employed, total (% of total employed): 74.2
# Unemployment, youth female (% of female labor force ages 15-24) (national estimate): 74.2
# Unemployment, youth male (% of male labor force ages 15-24) (national estimate): 74.2
# Youth literacy rate, population 15-24 years, female (%): 74.2
# Youth literacy rate, population 15-24 years, gender parity index (GPI): 74.2
# Youth literacy rate, population 15-24 years, male (%): 74.2
# Current account balance (BoP, current US$): 73.8
# Foreign direct investment, net (BoP, current US$): 73.8
# Industry, value added (constant LCU): 73.8
# Interest payments (% of revenue): 73.8
# International tourism, receipts for passenger transport items (current US$): 73.8
# Net primary income (BoP, current US$): 73.8
# Net trade in goods (BoP, current US$): 73.8
# Net trade in goods and services (BoP, current US$): 73.8
# Taxes on goods and services (% of revenue): 73.8
# Adjusted net national income (annual % growth): 73.4
# Adjusted net national income per capita (annual % growth): 73.4
# Adjusted net savings, including particulate emission damage (% of GNI): 73.4
# Adjusted savings: particulate emission damage (current US$): 73.4
# Burden of customs procedure, WEF (1=extremely inefficient to 7=extremely efficient): 73.4
# Changes in inventories (current LCU): 73.4
# Foreign direct investment, net outflows (% of GDP): 73.4
# Interest payments (% of expense): 73.4
# Net errors and omissions (BoP, current US$): 73.4
# Net financial account (BoP, current US$): 73.4
# Quality of port infrastructure, WEF (1=extremely underdeveloped to 7=well developed and efficient by international standards): 73.4
# Services, etc., value added (constant LCU): 73.4
# Taxes on income, profits and capital gains (% of revenue): 73.4
# Total reserves (includes gold, current US$): 73.4
# Total reserves minus gold (current US$): 73.4
# Wage and salaried workers, female (% of females employed): 73.4
# Wage and salary workers, male (% of males employed): 73.4
# Changes in inventories (current US$): 73.0
# Current account balance (% of GDP): 73.0
# Net ODA received per capita (current US$): 73.0
# Net official development assistance received (constant 2012 US$): 73.0
# Net official development assistance received (current US$): 73.0
# Reserves and related items (BoP, current US$): 73.0
# Revenue, excluding grants (% of GDP): 73.0
# Self-employed, female (% of females employed): 73.0
# Self-employed, male (% of males employed): 73.0
# Subsidies and other transfers (% of expense): 73.0
# Tax revenue (% of GDP): 73.0
# Manufacturing, value added (constant LCU): 72.6
# Marine protected areas (% of territorial waters): 72.6
# Net ODA received (% of GNI): 72.2
# Net bilateral aid flows from DAC donors, Belgium (current US$): 72.2
# Net bilateral aid flows from DAC donors, Norway (current US$): 72.2
# Population in the largest city (% of urban population): 72.2
# Contributing family workers, total (% of total employed): 71.8
# Net bilateral aid flows from DAC donors, Switzerland (current US$): 71.8
# Net official flows from UN agencies, UNFPA (current US$): 71.8
# Adjusted savings: net forest depletion (current US$): 71.4
# Consumer price index (2010 = 100): 71.4
# Firms using banks to finance investment (% of firms): 71.4
# Firms using banks to finance working capital (% of firms): 71.4
# Government expenditure on education as % of GDP (%): 71.4
# Lead time to export, median case (days): 71.4
# Losses due to theft, robbery, vandalism, and arson (% sales): 71.4
# Net bilateral aid flows from DAC donors, Sweden (current US$): 71.4
# Number of visits or required meetings with tax officials: 71.4
# Time spent dealing with the requirements of government regulations (% of senior management time): 71.4
# Adjusted savings: net national savings (current US$): 71.0
# Cash surplus/deficit (% of GDP): 71.0
# Expense (% of GDP): 71.0
# Firms offering formal training (% of firms): 71.0
# Net bilateral aid flows from DAC donors, Finland (current US$): 71.0
# Taxes on international trade (% of revenue): 71.0
# Contributing family workers, female (% of females employed): 70.6
# Contributing family workers, male (% of males employed): 70.6
# Delay in obtaining an electrical connection (days): 70.6
# Firms expected to give gifts in meetings with tax officials (% of firms): 70.6
# Firms with female participation in ownership (% of firms): 70.6
# Gross domestic income (constant 2005 US$): 70.6
# Gross savings (current LCU): 70.6
# Gross savings (current US$): 70.6
# Internationally-recognized quality certification (% of firms): 70.6
# Lead time to import, median case (days): 70.6
# Trademark applications, direct nonresident: 70.6
# Grants, excluding technical cooperation (BoP, current US$): 70.2
# Household final consumption expenditure per capita growth (annual %): 70.2
# Other taxes (% of revenue): 70.2
# Gross value added at factor cost (current LCU): 69.8
# Informal payments to public officials (% of firms): 69.8
# Expenditure on education as % of total government expenditure (%): 69.4
# Net current transfers from abroad (current LCU): 69.4
# Net current transfers from abroad (current US$): 69.4
# Official exchange rate (LCU per US$, period average): 69.4
# Charges for the use of intellectual property, receipts (BoP, current US$): 69.0
# Net bilateral aid flows from DAC donors, Ireland (current US$): 69.0
# Net capital account (BoP, current US$): 69.0
# Exports as a capacity to import (constant LCU): 68.5
# Exports of goods and services (constant LCU): 68.5
# Gross domestic income (constant LCU): 68.5
# Gross national expenditure (constant LCU): 68.5
# Gross national expenditure deflator (base year varies by country): 68.5
# Imports of goods and services (constant LCU): 68.5
# Net ODA received (% of gross capital formation): 68.5
# Portfolio Investment, net (BoP, current US$): 68.5
# Terms of trade adjustment (constant LCU): 68.5
# Value lost due to electrical outages (% of sales): 68.5
# Alternative and nuclear energy (% of total energy use): 68.1
# Average time to clear exports through customs (days): 68.1
# Bribery incidence (% of firms experiencing at least one bribe payment request): 68.1
# CO2 emissions from electricity and heat production, total (% of total fuel combustion): 68.1
# CO2 emissions from manufacturing industries and construction (% of total fuel combustion): 68.1
# CO2 emissions from other sectors, excluding residential buildings and commercial and public services (% of total fuel combustion): 68.1
# CO2 emissions from residential buildings and commercial and public services (% of total fuel combustion): 68.1
# CO2 emissions from transport (% of total fuel combustion): 68.1
# Combustible renewables and waste (% of total energy): 68.1
# Electric power transmission and distribution losses (% of output): 68.1
# Electricity production from renewable sources, excluding hydroelectric (kWh): 68.1
# Energy imports, net (% of energy use): 68.1
# GNI (constant LCU): 68.1
# GNI per capita (constant LCU): 68.1
# Merchandise exports to developing economies in Europe & Central Asia (% of total merchandise exports): 68.1
# Net intake rate to Grade 1 of primary education, both sexes (%): 68.1
# Net taxes on products (current LCU): 68.1
# Net taxes on products (current US$): 68.1
# New business density (new registrations per 1,000 people ages 15-64): 68.1
# Deposit interest rate (%): 67.7
# Droughts, floods, extreme temperatures (% of population, average 1990-2009): 67.7
# Firms competing against unregistered firms (% of firms): 67.7
# Methane emissions (kt of CO2 equivalent): 67.7
# Methane emissions in energy sector (thousand metric tons of CO2 equivalent): 67.7
# Net bilateral aid flows from DAC donors, Luxembourg (current US$): 67.7
# Nitrous oxide emissions (thousand metric tons of CO2 equivalent): 67.7
# Nitrous oxide emissions in energy sector (thousand metric tons of CO2 equivalent): 67.7
# Power outages in firms in a typical month (number): 67.7
# Time required to obtain an operating license (days): 67.7
# Binding coverage, all products (%): 67.3
# Binding coverage, manufactured products (%): 67.3
# Binding coverage, primary products (%): 67.3
# Bound rate, simple mean, all products (%): 67.3
# Bound rate, simple mean, manufactured products (%): 67.3
# Bound rate, simple mean, primary products (%): 67.3
# Final consumption expenditure, etc. (constant LCU): 67.3
# Gross capital formation (constant LCU): 67.3
# Merchandise imports from developing economies in Europe & Central Asia (% of total merchandise imports): 67.3
# Net official flows from UN agencies, UNAIDS (current US$): 67.3
# Agricultural methane emissions (% of total): 66.9
# Agricultural nitrous oxide emissions (% of total): 66.9
# Bank nonperforming loans to total gross loans (%): 66.9
# Electricity production from coal sources (% of total): 66.9
# Electricity production from hydroelectric sources (% of total): 66.9
# Electricity production from natural gas sources (% of total): 66.9
# Electricity production from nuclear sources (% of total): 66.9
# Electricity production from oil sources (% of total): 66.9
# Electricity production from oil, gas and coal sources (% of total): 66.9
# Electricity production from renewable sources, excluding hydroelectric (% of total): 66.9
# Energy related methane emissions (% of total): 66.9
# Gross value added at factor cost (constant LCU): 66.9
# Nitrous oxide emissions in industrial and energy processes (% of total nitrous oxide emissions): 66.9
# Expenditure on tertiary as % of government expenditure on education (%): 66.5
# Final consumption expenditure (constant LCU): 66.5
# Net intake rate to Grade 1 of primary education, female (%): 66.5
# Net intake rate to Grade 1 of primary education, male (%): 66.5
# Electric power consumption (kWh per capita): 66.1
# Firms formally registered when operations started (% of firms): 66.1
# General government final consumption expenditure (constant LCU): 66.1
# Other expense (% of expense): 66.1
# Technical cooperation grants (BoP, current US$): 66.1
# Trademark applications, direct resident: 66.1
# Completeness of total death reporting (% of reported total deaths to estimated total deaths): 65.7
# Gross fixed capital formation (constant LCU): 65.7
# Household final consumption expenditure (constant LCU): 65.7
# Household final consumption expenditure, etc. (constant LCU): 65.7
# Merchandise exports to developing economies in East Asia & Pacific (% of total merchandise exports): 65.7
# Net ODA received (% of imports of goods, services and primary income): 65.7
# Bank capital to assets ratio (%): 65.3
# Methodology assessment of statistical capacity (scale 0 - 100): 65.3
# Military expenditure (current LCU): 65.3
# Net bilateral aid flows from DAC donors, Denmark (current US$): 65.3
# Overall level of statistical capacity (scale 0 - 100): 65.3
# Periodicity and timeliness assessment of statistical capacity (scale 0 - 100): 65.3
# Source data assessment of statistical capacity (scale 0 - 100): 65.3
# Adjusted net savings, excluding particulate emission damage (current US$): 64.9
# Employers, total (% of employment): 64.9
# External balance on goods and services (constant LCU): 64.9
# Lending interest rate (%): 64.9
# Net taxes on products (constant LCU): 64.9
# Real interest rate (%): 64.9
# Vulnerable employment, total (% of total employment): 64.9
# Discrepancy in expenditure estimate of GDP (constant LCU): 64.5
# Vulnerable employment, female (% of female employment): 64.5
# Vulnerable employment, male (% of male employment): 64.5
# Employers, female (% of employment): 64.1
# Employers, male (% of employment): 64.1
# Net official flows from UN agencies, UNICEF (current US$): 64.1
# SF6 gas emissions (thousand metric tons of CO2 equivalent): 64.1
# Changes in inventories (constant LCU): 63.7
# Net financial flows, IBRD (NFL, current US$): 63.7
# Liner shipping connectivity index (maximum value in 2004 = 100): 63.3
# Military expenditure (% of central government expenditure): 63.3
# Net financial flows, IDA (NFL, current US$): 63.3
# Prevalence of underweight, weight for age (% of children under 5): 63.3
# Research and development expenditure (% of GDP): 63.3
# Net bilateral aid flows from DAC donors, Czech Republic (current US$): 62.9
# Prevalence of stunting, height for age (% of children under 5): 62.9
# HFC gas emissions (thousand metric tons of CO2 equivalent): 62.5
# Prevalence of wasting, weight for height (% of children under 5): 62.5
# ...
# Short-term debt (% of exports of goods, services and primary income): 52.8
# Short-term debt (% of total external debt): 52.8
# Total amount of debt rescheduled (current US$): 52.8
# Total change in external debt stocks (current US$): 52.8
# Undisbursed external debt, official creditors (UND, current US$): 52.8
# Undisbursed external debt, private creditors (UND, current US$): 52.8
# Undisbursed external debt, total (UND, current US$): 52.8
# Use of IMF credit (DOD, current US$): 52.8
# Borrowers from commercial banks (per 1,000 adults): 52.4
# Commitments, IDA (COM, current US$): 52.4
# Consumption of iodized salt (% of households): 52.4
# Current education expenditure, tertiary (% of total expenditure in tertiary public institutions): 52.4
# Debt buyback (current US$): 52.4
# Debt forgiveness grants (current US$): 52.4
# Debt stock reduction (current US$): 52.4
# EBRD, private nonguaranteed (NFL, current US$): 52.4
# External debt stocks (% of GNI): 52.4
# Interest payments on external debt (% of GNI): 52.4
# Interest rescheduled, private (current US$): 52.4
# Multilateral debt service (% of public and publicly guaranteed debt service): 52.4
# Net financial flows, RDB concessional (NFL, current US$): 52.4
# PPG, IDA (AMT, current US$): 52.4
# PPG, IDA (DIS, current US$): 52.4
# PPG, IDA (DOD, current US$): 52.4
# PPG, IDA (INT, current US$): 52.4
# PPG, IDA (NTR, current US$): 52.4
# PPG, IDA (TDS, current US$): 52.4
# Prevalence of overweight, weight for height, female (% of children under 5): 52.4
# Principal rescheduled, private (current US$): 52.4
# Currency composition of PPG debt, Deutsche mark (%): 52.0
# Currency composition of PPG debt, French franc (%): 52.0
# Labor force with primary education, female (% of female labor force): 52.0
# Labor force with primary education, male (% of male labor force): 52.0
# Labor force with secondary education, female (% of female labor force): 52.0
# Labor force with secondary education, male (% of male labor force): 52.0
# Labor force with tertiary education, female (% of female labor force): 52.0
# Labor force with tertiary education, male (% of male labor force): 52.0
# Net incurrence of liabilities, foreign (current LCU): 52.0
# Prevalence of severe wasting, weight for height, male (% of children under 5): 52.0
# All education staff compensation, total (% of total expenditure in public institutions): 51.6
# Net incurrence of liabilities, domestic (current LCU): 51.6
# Poverty headcount ratio at national poverty lines (% of population): 51.6
# Prevalence of severe wasting, weight for height, female (% of children under 5): 51.6
# Railways, goods transported (million ton-km): 51.6
# Share of youth not in education, employment, or training, total (% of youth population): 51.6
# ARI treatment (% of children under 5 taken to a health provider): 51.2
# Broad money (% of GDP): 51.2
# Claims on central government, etc. (% GDP): 51.2
# Claims on other sectors of the domestic economy (% of GDP): 51.2
# Domestic credit provided by financial sector (% of GDP): 51.2
# Domestic credit to private sector (% of GDP): 51.2
# Domestic credit to private sector by banks (% of GDP): 51.2
# Money and quasi money (M2) as % of GDP: 51.2
# Net current transfers from abroad (constant LCU): 51.2
# Share of youth not in education, employment, or training, female (% of female youth population): 50.8
# Share of youth not in education, employment, or training, male (% of male youth population): 50.8
# External debt stocks (% of exports of goods, services and primary income): 50.0
# Gross fixed capital formation, private sector (% of GDP): 50.0
# Interest payments on external debt (% of exports of goods, services and primary income): 50.0
# Stocks traded, turnover ratio of domestic shares (%): 50.0
# Total debt service (% of exports of goods, services and primary income): 50.0
# Long-term unemployment (% of total unemployment): 49.6
# Prevalence of HIV, total (% of population ages 15-49): 49.6
# Newborns protected against tetanus (%): 49.2
# Prevalence of HIV, female (% ages 15-24): 48.4
# Prevalence of HIV, male (% ages 15-24): 48.4
# Social contributions (% of revenue): 48.4
# Stocks traded, total value (% of GDP): 48.4
# Stocks traded, total value (current US$): 48.4
# Railways, passengers carried (million passenger-km): 48.0
# Women's share of population ages 15+ living with HIV (%): 48.0
# Agricultural irrigated land (% of total agricultural land): 47.6
# Fertilizer consumption (% of fertilizer production): 47.6
# Diarrhea treatment (% of children under 5 receiving oral rehydration and continued feeding): 47.2
# Present value of external debt (current US$): 47.2
# Antiretroviral therapy coverage (% of people living with HIV): 46.8
# Diarrhea treatment (% of children under 5 who received ORS packet): 46.8
# Technicians in R&D (per million people): 46.8
# Gross domestic savings (constant LCU): 46.4
# Rail lines (total route-km): 46.4
# All education staff compensation, tertiary (% of total expenditure in tertiary public institutions): 46.0
# Broad money (current LCU): 46.0
# Broad money growth (annual %): 46.0
# Broad money to total reserves ratio: 46.0
# Claims on central government (annual growth as % of broad money): 46.0
# Claims on other sectors of the domestic economy (annual growth as % of broad money): 46.0
# Claims on private sector (annual growth as % of broad money): 46.0
# Money and quasi money (M2) (current LCU): 46.0
# Money and quasi money (M2) to total reserves ratio: 46.0
# Money and quasi money growth (annual %): 46.0
# Net domestic credit (current LCU): 46.0
# Net foreign assets (current LCU): 46.0
# Population in urban agglomerations of more than 1 million: 46.0
# Arms exports (SIPRI trend indicator values): 45.6
# Investment in energy with private participation (current US$): 45.6
# Money (current LCU): 45.6
# Completeness of birth registration, rural (%): 44.8
# Completeness of birth registration, urban (%): 44.8
# Food, beverages and tobacco (% of value added in manufacturing): 44.8
# Long-term unemployment, female (% of female unemployment): 44.8
# Long-term unemployment, male (% of male unemployment): 44.8
# Other manufacturing (% of value added in manufacturing): 44.8
# CPIA building human resources rating (1=low to 6=high): 44.4
# CPIA business regulatory environment rating (1=low to 6=high): 44.4
# CPIA debt policy rating (1=low to 6=high): 44.4
# CPIA economic management cluster average (1=low to 6=high): 44.4
# CPIA efficiency of revenue mobilization rating (1=low to 6=high): 44.4
# CPIA equity of public resource use rating (1=low to 6=high): 44.4
# CPIA financial sector rating (1=low to 6=high): 44.4
# CPIA fiscal policy rating (1=low to 6=high): 44.4
# CPIA gender equality rating (1=low to 6=high): 44.4
# CPIA macroeconomic management rating (1=low to 6=high): 44.4
# CPIA policy and institutions for environmental sustainability rating (1=low to 6=high): 44.4
# CPIA property rights and rule-based governance rating (1=low to 6=high): 44.4
# CPIA public sector management and institutions cluster average (1=low to 6=high): 44.4
# CPIA quality of budgetary and financial management rating (1=low to 6=high): 44.4
# CPIA quality of public administration rating (1=low to 6=high): 44.4
# CPIA structural policies cluster average (1=low to 6=high): 44.4
# CPIA trade rating (1=low to 6=high): 44.4
# CPIA transparency, accountability, and corruption in the public sector rating (1=low to 6=high): 44.4
# Depositors with commercial banks (per 1,000 adults): 44.4
# IDA resource allocation index (1=low to 6=high): 44.4
# Textiles and clothing (% of value added in manufacturing): 44.4
# CPIA policies for social inclusion/equity cluster average (1=low to 6=high): 44.0
# Gross fixed capital formation, private sector (current LCU): 44.0
# CPIA social protection rating (1=low to 6=high): 43.5
# Net ODA received (% of central government expense): 43.5
# Chemicals (% of value added in manufacturing): 42.7
# Net bilateral aid flows from DAC donors, Slovenia (current US$): 42.7
# Coverage (%) -All Social Protection and Labor: 42.3
# Machinery and transport equipment (% of value added in manufacturing): 41.9
# Social contributions (current LCU): 41.9
# Part time employment, total (% of total employment): 41.1
# Coverage (%) - All Social Assistance: 40.7
# Urban poverty headcount ratio at national poverty lines (% of urban population): 40.7
# Point-of-sale terminals (per 100,000 adults): 40.3
# Rural poverty headcount ratio at national poverty lines (% of rural population): 40.3
# Part time employment, female (% of total female employment): 39.9
# Part time employment, male (% of total male employment): 39.9
# Present value of external debt (% of GNI): 39.9
# Part time employment, female (% of total part time employment): 39.5
# Vitamin A supplementation coverage rate (% of children ages 6-59 months): 39.5
# Benefits incidence in poorest quintile (%) -All Social Protection and Labor: 39.1
# Central government debt, total (% of GDP): 39.1
# Adequacy of social protection and labor programs (% of total welfare of beneficiary households): 38.7
# Children in employment, female (% of female children ages 7-14): 38.7
# Children in employment, male (% of male children ages 7-14): 38.7
# Children in employment, study and work (% of children in employment, ages 7-14): 38.7
# Children in employment, study and work, female (% of female children in employment, ages 7-14): 38.7
# Children in employment, study and work, male (% of male children in employment, ages 7-14): 38.7
# Children in employment, total (% of children ages 7-14): 38.7
# Children in employment, work only (% of children in employment, ages 7-14): 38.7
# Children in employment, work only, female (% of female children in employment, ages 7-14): 38.7
# Children in employment, work only, male (% of male children in employment, ages 7-14): 38.7
# Coverage (%) - All Social Insurance: 38.7
# Net bilateral aid flows from DAC donors, Slovak Republic (current US$): 38.7
# Risk premium on lending (lending rate minus treasury bill rate, %): 38.7
# Annualized average growth rate in per capita real survey mean consumption or income, bottom 40% of population (%): 37.9
# Annualized average growth rate in per capita real survey mean consumption or income, total population (%): 37.9
# Real effective exchange rate index (2010 = 100): 37.9
# Benefits incidence in poorest quintile (%) - All Social Insurance: 37.1
# Investment in transport with private participation (current US$): 37.1
# Adequacy of social insurance programs (% of total welfare of beneficiary households): 36.7
# Children in employment, unpaid family workers (% of children in employment, ages 7-14): 36.3
# Children in employment, unpaid family workers, female (% of female children in employment, ages 7-14): 36.3
# Children in employment, unpaid family workers, male (% of male children in employment, ages 7-14): 36.3
# Poverty gap at national poverty lines (%): 36.3
# Average working hours of children, study and work, ages 7-14 (hours per week): 35.9
# Average working hours of children, study and work, female, ages 7-14 (hours per week): 35.9
# Average working hours of children, study and work, male, ages 7-14 (hours per week): 35.9
# Benefits incidence in poorest quintile (%) - All Social Assistance: 35.9
# Adequacy of social safety net programs (% of total welfare of beneficiary households): 35.5
# Children in employment, wage workers (% of children in employment, ages 7-14): 35.5
# Children in employment, wage workers, female (% of female children in employment, ages 7-14): 35.5
# Children in employment, wage workers, male (% of male children in employment, ages 7-14): 35.5
# Central government debt, total (current LCU): 35.1
# S&P Global Equity Indices (annual % change): 33.9
# Survey mean consumption or income per capita, bottom 40% of population (2011 PPP $ per day): 33.9
# Survey mean consumption or income per capita, total population (2011 PPP $ per day): 33.9
# Average working hours of children, working only, ages 7-14 (hours per week): 33.5
# Average working hours of children, working only, male, ages 7-14 (hours per week): 33.5
# Disaster risk reduction progress score (1-5 scale; 5=best): 33.5
# Children (0-14) living with HIV: 33.1
# Average working hours of children, working only, female, ages 7-14 (hours per week): 32.7
# Wholesale price index (2010 = 100): 32.7
# GHG net emissions/removals by LUCF (Mt of CO2 equivalent): 31.9
# Rural poverty gap at national poverty lines (%): 31.0
# Urban poverty gap at national poverty lines (%): 31.0
# Wanted fertility rate (births per woman): 30.6
# Women who believe a husband is justified in beating his wife (any of five reasons) (%): 30.2
# Women who believe a husband is justified in beating his wife when she goes out without telling him (%): 30.2
# Women who believe a husband is justified in beating his wife when she neglects the children (%): 30.2
# Teenage mothers (% of women ages 15-19 who have had children or are currently pregnant): 29.8
# Women who believe a husband is justified in beating his wife when she argues with him (%): 29.8
# Women who believe a husband is justified in beating his wife when she burns the food (%): 29.8
# Women who believe a husband is justified in beating his wife when she refuses sex with him (%): 29.8
# Battle-related deaths (number of people): 29.0
# Internally displaced persons (number, high estimate): 29.0
# Children with fever receiving antimalarial drugs (% of children under age 5 with fever): 28.6
# Community health workers (per 1,000 people): 28.6
# Condom use, population ages 15-24, female (% of females ages 15-24): 27.4
# Female headed households (% of households with a female head): 27.4
# Present value of external debt (% of exports of goods, services and primary income): 27.4
# Net bilateral aid flows from DAC donors, Iceland (current US$): 27.0
# Taxes on exports (% of tax revenue): 26.2
# Taxes on exports (current LCU): 26.2
# Use of insecticide-treated bed nets (% of under-5 population): 26.2
# Net official aid received (constant 2012 US$): 25.4
# Net official aid received (current US$): 25.4
# Investment in water and sanitation with private participation (current US$): 25.0
# Quasi money (current LCU): 24.6
# Child employment in agriculture (% of economically active children ages 7-14): 24.2
# Child employment in agriculture, female (% of female economically active children ages 7-14): 24.2
# Child employment in agriculture, male (% of male economically active children ages 7-14): 24.2
# Child employment in manufacturing (% of economically active children ages 7-14): 24.2
# Child employment in services (% of economically active children ages 7-14): 24.2
# Child employment in services, female (% of female economically active children ages 7-14): 24.2
# Child employment in services, male (% of male economically active children ages 7-14): 24.2
# Condom use, population ages 15-24, male (% of males ages 15-24): 24.2
# Child employment in manufacturing, female (% of female economically active children ages 7-14): 23.8
# Child employment in manufacturing, male (% of male economically active children ages 7-14): 23.8
# Coverage (%) - All Labor Market: 22.6
# Children in employment, self-employed (% of children in employment, ages 7-14): 20.6
# Children in employment, self-employed, female (% of female children in employment, ages 7-14): 20.6
# Children in employment, self-employed, male (% of male children in employment, ages 7-14): 20.6
# Net official flows from UN agencies, UNPBF (current US$): 19.0
# Internally displaced persons (number, low estimate): 17.7
# Adequacy of unemployment benefits and ALMP (% of total welfare of beneficiary households): 14.5
# Benefits incidence in poorest quintile (%) - All Labor Market: 14.5
# Quasi-liquid liabilities (% of GDP): 11.7
# Liquid liabilities (M3) as % of GDP: 11.3
# Net official flows from UN agencies, UNRWA (current US$): 9.7
# Net income from abroad (constant LCU): 8.1
# Net official flows from UN agencies, UNECE (current US$): 8.1
# Presence of peace keepers (number of troops, police, and military observers in mandate): 8.1
# Survey mean consumption or income per capita, bottom 40% of population (2005 PPP $ per day): 1.6
# Survey mean consumption or income per capita, total population (2005 PPP $ per day): 1.6
# Procedures to enforce a contract (number): 0.0

# %%
# call this function after creating a csv for a single country, for a single year, for a group of indicators.
# this function exports the indicator names to a csv.
def create_group_csv(csv_dwnld, save_to):

    data = pd.read_csv(os.path.join(cur_dir, csv_dwnld))
    education_stats = data['Series Name'].tolist()

    with open(save_to, 'w') as f:
        writer = csv.writer(f)
        writer.writerow(education_stats)
        
## And then this gets the corresponding indicator list.
def get_indicator_list_from_csv(csv_file):
    with open(csv_file) as f:
        reader = csv.reader(f)
        your_list = list(reader)
    return your_list[0]

## example usage
create_group_csv('Data_Extract_From_World_Development_Indicators_Data.csv', 'health.csv')
health_indicators = get_indicator_list_from_csv('health.csv')
