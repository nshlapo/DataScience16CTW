# %%
import pandas as pd

data = pd.read_csv('WDI_Data.csv')
    

data['21st'] = data.ix[:, '2000':].mean(axis=1)
print sum(data['21st'].isnull())

# data[data['Country Name']=='Caribbean small states'].head()
# Out:
# 104967
#                 Country Name Country Code  \
# 1345  Caribbean small states          CSS
# 1346  Caribbean small states          CSS
# 1347  Caribbean small states          CSS
# 1348  Caribbean small states          CSS
# 1349  Caribbean small states          CSS
#
#                                          Indicator Name     Indicator Code  \
# 1345  2005 PPP conversion factor, GDP (LCU per inter...      PA.NUS.PPP.05
# 1346  2005 PPP conversion factor, private consumptio...  PA.NUS.PRVT.PP.05
# 1347            Access to electricity (% of population)     EG.ELC.ACCS.ZS
# 1348  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 1349  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
#
#       1960  1961  1962  1963  1964  1965    ...      2007  2008  2009  \
# 1345   NaN   NaN   NaN   NaN   NaN   NaN    ...       NaN   NaN   NaN
# 1346   NaN   NaN   NaN   NaN   NaN   NaN    ...       NaN   NaN   NaN
# 1347   NaN   NaN   NaN   NaN   NaN   NaN    ...       NaN   NaN   NaN
# 1348   NaN   NaN   NaN   NaN   NaN   NaN    ...       NaN   NaN   NaN
# 1349   NaN   NaN   NaN   NaN   NaN   NaN    ...       NaN   NaN   NaN
#
#            2010  2011       2012  2013  2014  2015       21st
# 1345        NaN   NaN        NaN   NaN   NaN   NaN        NaN
# 1346        NaN   NaN        NaN   NaN   NaN   NaN        NaN
# 1347  92.382326   NaN  93.456157   NaN   NaN   NaN  91.265269
# 1348  86.470325   NaN  88.597907   NaN   NaN   NaN  85.828303
# 1349  98.899017   NaN  98.335671   NaN   NaN   NaN  97.025869
#
# [5 rows x 61 columns]

# %%
grouped = data.groupby('Indicator Name')

def one_year(year='21st'):
    indic_dict = {}
    for indicator, group in grouped:
        for index, row in group.iterrows():
            if indicator not in indic_dict:
                indic_dict[indicator] = []

            indic_dict[indicator].append(row[year])

    for indicator, group in grouped:
        names = group['Country Name'].tolist()
        break   
        
    return pd.DataFrame(indic_dict, index=names)

# %%
# other_names = [name for name, group in data.groupby('Country Name')]

# for i in xrange(len(names)):
#     print names[i], '  ', other_names[i]

df = one_year()       

print df.head()
# Out:
#                                          2005 PPP conversion factor, GDP (LCU per international $)  \
# Arab World                                                                             NaN
# Caribbean small states                                                                 NaN
# Central Europe and the Baltics                                                         NaN
# East Asia & Pacific (all income levels)                                                NaN
# East Asia & Pacific (developing only)                                                  NaN
#
#                                          2005 PPP conversion factor, private consumption (LCU per international $)  \
# Arab World                                                                             NaN
# Caribbean small states                                                                 NaN
# Central Europe and the Baltics                                                         NaN
# East Asia & Pacific (all income levels)                                                NaN
# East Asia & Pacific (developing only)                                                  NaN
#
#                                          ARI treatment (% of children under 5 taken to a health provider)  \
# Arab World                                                                       63.479760
# Caribbean small states                                                           56.767443
# Central Europe and the Baltics                                                         NaN
# East Asia & Pacific (all income levels)                                                NaN
# East Asia & Pacific (developing only)                                                  NaN
#
#                                          Access to electricity (% of population)  \
# Arab World                                                             83.383309
# Caribbean small states                                                 91.265269
# Central Europe and the Baltics                                        100.000000
# East Asia & Pacific (all income levels)                                94.527311
# East Asia & Pacific (developing only)                                  93.954317
#
#                                          Access to electricity, rural (% of rural population)  \
# Arab World                                                                       70.582930
# Caribbean small states                                                           85.828303
# Central Europe and the Baltics                                                  100.000000
# East Asia & Pacific (all income levels)                                          90.133535
# East Asia & Pacific (developing only)                                            89.885953
#
#                                          Access to electricity, urban (% of urban population)  \
# Arab World                                                                       93.544829
# Caribbean small states                                                           97.025869
# Central Europe and the Baltics                                                  100.000000
# East Asia & Pacific (all income levels)                                          98.258126
# East Asia & Pacific (developing only)                                            97.922370
#
#                                          Access to non-solid fuel (% of population)  \
# Arab World                                                                84.718027
# Caribbean small states                                                    89.785902
# Central Europe and the Baltics                                            91.705892
# East Asia & Pacific (all income levels)                                   54.850091
# East Asia & Pacific (developing only)                                     49.978565
#
#                                          Access to non-solid fuel, rural (% of rural population)  \
# Arab World                                                                       74.779244
# Caribbean small states                                                           88.899618
# Central Europe and the Baltics                                                   87.768083
# East Asia & Pacific (all income levels)                                          22.631039
# East Asia & Pacific (developing only)                                            20.847465
#
#                                          Access to non-solid fuel, urban (% of urban population)  \
# Arab World                                                                       94.755814
# Caribbean small states                                                           96.900029
# Central Europe and the Baltics                                                   96.420631
# East Asia & Pacific (all income levels)                                          88.879970
# East Asia & Pacific (developing only)                                            86.729873
#
#                                          Adequacy of social insurance programs (% of total welfare of beneficiary households)  \
# Arab World                                                                             NaN
# Caribbean small states                                                                 NaN
# Central Europe and the Baltics                                                         NaN
# East Asia & Pacific (all income levels)                                                NaN
# East Asia & Pacific (developing only)                                                  NaN
#
#                                                                  ...                            \
# Arab World                                                       ...
# Caribbean small states                                           ...
# Central Europe and the Baltics                                   ...
# East Asia & Pacific (all income levels)                          ...
# East Asia & Pacific (developing only)                            ...
#
#                                          Women who believe a husband is justified in beating his wife when she argues with him (%)  \
# Arab World                                                                             NaN
# Caribbean small states                                                                 NaN
# Central Europe and the Baltics                                                         NaN
# East Asia & Pacific (all income levels)                                                NaN
# East Asia & Pacific (developing only)                                                  NaN
#
#                                          Women who believe a husband is justified in beating his wife when she burns the food (%)  \
# Arab World                                                                             NaN
# Caribbean small states                                                                 NaN
# Central Europe and the Baltics                                                         NaN
# East Asia & Pacific (all income levels)                                                NaN
# East Asia & Pacific (developing only)                                                  NaN
#
#                                          Women who believe a husband is justified in beating his wife when she goes out without telling him (%)  \
# Arab World                                                                             NaN
# Caribbean small states                                                                 NaN
# Central Europe and the Baltics                                                         NaN
# East Asia & Pacific (all income levels)                                                NaN
# East Asia & Pacific (developing only)                                                  NaN
#
#                                          Women who believe a husband is justified in beating his wife when she neglects the children (%)  \
# Arab World                                                                             NaN
# Caribbean small states                                                                 NaN
# Central Europe and the Baltics                                                         NaN
# East Asia & Pacific (all income levels)                                                NaN
# East Asia & Pacific (developing only)                                                  NaN
#
#                                          Women who believe a husband is justified in beating his wife when she refuses sex with him (%)  \
# Arab World                                                                             NaN
# Caribbean small states                                                                 NaN
# Central Europe and the Baltics                                                         NaN
# East Asia & Pacific (all income levels)                                                NaN
# East Asia & Pacific (developing only)                                                  NaN
#
#                                          Women's share of population ages 15+ living with HIV (%)  \
# Arab World                                                                       53.293367
# Caribbean small states                                                                 NaN
# Central Europe and the Baltics                                                         NaN
# East Asia & Pacific (all income levels)                                                NaN
# East Asia & Pacific (developing only)                                                  NaN
#
#                                          Youth literacy rate, population 15-24 years, both sexes (%)  \
# Arab World                                                                       85.137158
# Caribbean small states                                                           95.124193
# Central Europe and the Baltics                                                   99.372937
# East Asia & Pacific (all income levels)                                          98.441115
# East Asia & Pacific (developing only)                                            98.357896
#
#                                          Youth literacy rate, population 15-24 years, female (%)  \
# Arab World                                                                       80.777277
# Caribbean small states                                                           96.734796
# Central Europe and the Baltics                                                   99.380525
# East Asia & Pacific (all income levels)                                          98.259185
# East Asia & Pacific (developing only)                                            98.165143
#
#                                          Youth literacy rate, population 15-24 years, gender parity index (GPI)  \
# Arab World                                                                        0.902781
# Caribbean small states                                                            1.033308
# Central Europe and the Baltics                                                    1.000150
# East Asia & Pacific (all income levels)                                           0.996344
# East Asia & Pacific (developing only)                                             0.996124
#
#                                          Youth literacy rate, population 15-24 years, male (%)
# Arab World                                                                       89.395626
# Caribbean small states                                                           93.622254
# Central Europe and the Baltics                                                   99.365623
# East Asia & Pacific (all income levels)                                          98.618957
# East Asia & Pacific (developing only)                                            98.546132
#
# [5 rows x 1345 columns]
